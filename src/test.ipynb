# %%
from backend.vector_store import get_vector_store, seed_vector_store, similarity_search
from dotenv import load_dotenv
import os

# Load variables from .env file
load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
store = get_vector_store(api_key)

# %%
json_query = {
                "$and": [
                    # {
                    #     "price": {
                    #         "$gte": 1000 
                    #     }
                    # }, 
                    {
                        "price": {
                            "$lte": 900 
                        }
                    },
                    {
                        "property_type": "Entire rental unit"
                    },
                    {
                        "neighbourhood_cleansed": "Miguel Hidalgo"
                    },
                    {
                        "$or": [
                            {
                                "amenities" : {
                                    "$contains": "Microwave"
                                }
                            },
                             {
                                "amenities" : {
                                    "$contains": 'Kitchen'
                                }
                            },
                        ]
                    }
                ]
            }

# %%
query_results = store.similarity_search(
    query="near from the university with roof garden",
    k=10,
    filter=json_query
)

# %%
query_results
# Out:
# [Document(id='1019889143626204896', metadata={'bathrooms': 2.0, 'room_type': 'Entire home/apt', 'neighbourhood_cleansed': 'Miguel Hidalgo', 'price': 900.0, 'latitude': 19.4, 'amenities': ['Gas stove', 'Blender', 'Coffee', 'Dedicated workspace', 'Portable fans', 'Oven', 'Kitchen', 'Cooking basics', 'Wifi', 'Dishes and silverware', 'Dining table', 'Microwave', 'Free street parking', 'Coffee maker: espresso machine', 'Essentials', 'Hot water', 'Exterior security cameras on property', 'Long term stays allowed', 'Clothing storage: closet', 'Cleaning products', 'TV', 'Refrigerator'], 'has_availability': True, 'review_scores_accuracy': 5.0, 'longitude': -99.18, 'maximum_nights': 365.0, 'property_type': 'Entire rental unit', 'bedrooms': 2.0, 'minimum_nights': 4.0, 'bathrooms_text': '2 baths', 'beds': 2.0}, page_content='Nice apartment in Col. Escandón I Section. Two bedrooms: one with a queen size bed, a TV, a TV, a closet and a full bathroom; the second with a single bed and a work area. Ki
# ...

# %%
len(store.get()["ids"])
# Out:
# 200

# %%
query_results
# Out:
# [Document(id='1019889143626204896', metadata={'bathrooms': 2.0, 'room_type': 'Entire home/apt', 'neighbourhood_cleansed': 'Miguel Hidalgo', 'price': 900.0, 'latitude': 19.4, 'amenities': ['Gas stove', 'Blender', 'Coffee', 'Dedicated workspace', 'Portable fans', 'Oven', 'Kitchen', 'Cooking basics', 'Wifi', 'Dishes and silverware', 'Dining table', 'Microwave', 'Free street parking', 'Coffee maker: espresso machine', 'Essentials', 'Hot water', 'Exterior security cameras on property', 'Long term stays allowed', 'Clothing storage: closet', 'Cleaning products', 'TV', 'Refrigerator'], 'has_availability': True, 'review_scores_accuracy': 5.0, 'longitude': -99.18, 'maximum_nights': 365.0, 'property_type': 'Entire rental unit', 'bedrooms': 2.0, 'minimum_nights': 4.0, 'bathrooms_text': '2 baths', 'beds': 2.0}, page_content='Nice apartment in Col. Escandón I Section. Two bedrooms: one with a queen size bed, a TV, a TV, a closet and a full bathroom; the second with a single bed and a work area. Ki
# ...

# %%
query_results[0].to_json()['kwargs']["metadata"]
# Out:
# {'bathrooms': 2.0,
#  'room_type': 'Entire home/apt',
#  'neighbourhood_cleansed': 'Miguel Hidalgo',
#  'price': 900.0,
#  'latitude': 19.4,
#  'amenities': ['Gas stove',
#   'Blender',
#   'Coffee',
#   'Dedicated workspace',
#   'Portable fans',
#   'Oven',
#   'Kitchen',
#   'Cooking basics',
#   'Wifi',
#   'Dishes and silverware',
#   'Dining table',
#   'Microwave',
#   'Free street parking',
#   'Coffee maker: espresso machine',
#   'Essentials',
#   'Hot water',
#   'Exterior security cameras on property',
#   'Long term stays allowed',
#   'Clothing storage: closet',
#   'Cleaning products',
#   'TV',
#   'Refrigerator'],
#  'has_availability': True,
#  'review_scores_accuracy': 5.0,
#  'longitude': -99.18,
#  'maximum_nights': 365.0,
#  'property_type': 'Entire rental unit',
#  'bedrooms': 2.0,
#  'minimum_nights': 4.0,
#  'bathrooms_text': '2 baths',
#  'beds': 2.0}

# %%
props = [{'id': '621708243762204671', 'metadata': {'maximum_nights': 1125.0, 'property_type': 'Entire serviced apartment', 'review_scores_accuracy': 4.83, 'amenities': ['Shampoo', 'Carbon monoxide alarm', 'Conditioner', 'Dedicated workspace', 'Smoking allowed', 'Free dryer \\u2013 In unit', 'Pets allowed', 'Hair dryer', 'Freezer', 'Drying rack for clothing', 'Shower gel', 'First aid kit', 'Iron', 'Mabe oven', 'Essentials', 'Mountain view', 'Dishes and silverware', 'Heating', 'Mabe gas stove', 'Hot water', 'Fire extinguisher', 'Pack \\u2019n play/Travel crib - always at the listing', 'Blender', 'Private patio or balcony', 'Private gym in building', 'Elevator', 'Cooking basics', 'Clothing storage: closet', 'Kitchen', 'Long term stays allowed', 'Fast wifi \\u2013 55 Mbps', 'Free parking on premises', 'Single level home', 'Hangers', 'Self check-in', 'Free washer \\u2013 In unit', 'Exercise equipment', 'Room-darkening shades', 'Refrigerator', 'Crib - always at the listing', 'Smoke alarm', 'Coffee maker', 'Dining table', 'Keypad', 'Coffee', 'Body soap', '115 inch HDTV with Netflix', 'Roku', 'standard cable', 'Microwave', 'Extra pillows and blankets', 'Bed linens', 'Exterior security cameras on property'], 'bathrooms_text': '2 baths', 'latitude': 19.32, 'bedrooms': 2.0, 'has_availability': True, 'room_type': 'Entire home/apt', 'beds': 3.0, 'longitude': -99.14, 'bathrooms': 2.0, 'minimum_nights': 2.0, 'price': 1449.0, 'neighbourhood_cleansed': 'Coyoacán'}, 'page_content': 'Brand new apartment in the South of Mexico City. In the Plaza Comercial of the Museo del Automóvil and walking from the Diego Rivera Museum (Anahuacalli). Designer-decorated with 1800-thread-count sheets, parking, one block from the light rail, in front of Walmart and with a first-class gym at the bottom of the building. The location of this development is key to the South of Mexico City, located on Av. División del Norte and a few minutes from roads such as Calz. Tlalpan, Miguel Ángel de Quevedo and Periférico Sur', 'type': 'Document'}, {'id': '1368229336165968358', 'metadata': {'maximum_nights': 1125.0, 'room_type': 'Entire home/apt', 'property_type': 'Entire condo', 'has_availability': True, 'longitude': -99.15, 'latitude': 19.44, 'neighbourhood_cleansed': 'Cuauhtémoc', 'price': 1769.0, 'minimum_nights': 1.0, 'bathrooms_text': '2 baths', 'beds': 2.0, 'bathrooms': 2.0, 'review_scores_accuracy': 4.98, 'bedrooms': 2.0, 'amenities': ['Carbon monoxide alarm', 'Oven', 'Pets allowed', 'Hair dryer', 'Freezer', 'Shower gel', 'Iron', 'Dishes and silverware', 'Cleaning products', 'Hot water', 'Fire extinguisher', 'Blender', 'TV', 'Board games', 'Elevator', 'Cooking basics', 'Kitchen', 'Toaster', 'Long term stays allowed', 'Clothing storage', 'Washer', 'Wifi', 'Self check-in', 'Portable fans', 'Free parking on premises', 'Hangers', 'Single level home', 'Safe', 'Room-darkening shades', 'Books and reading material', 'Refrigerator', 'Stove', 'Smoke alarm', 'Hot water kettle', 'Coffee maker', 'Dining table', 'Keypad', 'Coffee', 'Microwave', 'Extra pillows and blankets', 'Exterior security cameras on property']}, 'page_content': "A full apartment in the heart of the Historic Center. Two real bedrooms, two full bathrooms, an equipped kitchen, and something that is almost nonexistent in this area: private parking.A 5-minute walk from the Palacio de Bellas Artes and the Alameda. 10 minutes from the Zócalo. Surrounded by downtown's best restaurants, neighborhood markets, and specialty cafes. Everything is within walking distance or accessible by metro from the door.Ideal for families, couples traveling together, or anyone who wants to experience the real Mexico City without paying for a hotel.", 'type': 'Document'}, {'id': '1452990759844812728', 'metadata': {'has_availability': True, 'bathrooms_text': '2 baths', 'beds': 4.0, 'maximum_nights': 365.0, 'latitude': 19.47, 'price': 1321.0, 'minimum_nights': 1.0, 'bathrooms': 2.0, 'bedrooms': 3.0, 'amenities': ['Shampoo', 'Carbon monoxide alarm', 'Dedicated workspace', 'Smart lock', 'Oven', 'Free dryer \\u2013 In unit', 'Hair dryer', 'First aid kit', 'Iron', 'Essentials', 'Dishes and silverware', 'Cleaning products', 'Hot water', 'Fire extinguisher', 'Blender', 'TV', 'Elevator', 'Cooking basics', 'Kitchen', 'Patio or balcony', 'Washer', 'Wifi', 'Self check-in', 'Portable fans', 'Free parking on premises', 'Hangers', 'Luggage dropoff allowed', 'Room-darkening shades', 'Stove', 'Refrigerator', 'Smoke alarm', 'Coffee maker', 'Dining table', 'Coffee', 'Body soap', 'Microwave', 'Extra pillows and blankets', 'Bed linens', 'Exterior security cameras on property'], 'room_type': 'Entire home/apt', 'neighbourhood_cleansed': 'Azcapotzalco', 'longitude': -99.18, 'review_scores_accuracy': 4.91, 'property_type': 'Entire condo'}, 'page_content': 'Welcome to your next favorite spot in Mexico City! If you are looking for a place where your family can relax in complete safety and peace, this is a vibrant and cozy space with 3 bedrooms, a fully equipped kitchen, a laundry center, and a living-dining room. SHARED PARKING SPACE FOR 1 VEHICLE, MAXIMUM HEIGHT 1.50\xa0m (YOU LEAVE YOUR CAR KEYS); NO LARGE TRUCKS/VANS. Near Arena Cdmx, Tecnoparque, Parque Bicentenario IPAD, Ex Fábrica de Harina Plan Sexenal, Vallejo, Pantaco. 30 minutes from the Zócalo, Reforma, Polanco, Satélite-Toreo.', 'type': 'Document'}, {'id': '28697832', 'metadata': {'longitude': -99.23, 'price': 1712.0, 'latitude': 19.32, 'has_availability': True, 'review_scores_accuracy': 4.56, 'maximum_nights': 1125.0, 'bathrooms_text': '1 bath', 'beds': 2.0, 'property_type': 'Entire rental unit', 'amenities': ['Shampoo', 'Hot water', 'Long term stays allowed', 'Dedicated workspace', 'Building staff', 'Patio or balcony', 'Fire pit', 'Shared backyard', 'Wifi', 'Self check-in', 'Free parking on premises', 'Hangers', 'Kitchen', 'Essentials', 'Extra pillows and blankets', 'Bed linens', 'Luggage dropoff allowed', 'Free street parking'], 'bathrooms': 1.0, 'bedrooms': 2.0, 'neighbourhood_cleansed': 'La Magdalena Contreras', 'minimum_nights': 5.0, 'room_type': 'Entire home/apt'}, 'page_content': 'Apartment RentalsSpacious and comfortable. Very close to the CDMX stadium. Both bedrooms have a closet, 1 full bathroom, a sitting area; living-dining room, kitchen, and 1 parking space. Fully furnished with utilities included (electricity, water, gas, and internet). Safe and quiet residential area overlooking green spaces that promote rest and relaxation.Ten minutes from the Periférico and the Poniente–Santa Fe Superhighway, Hotel Camino Real, Artz Pedregal, Hospital Ángeles, and the National Human Rights Commission (CNDH)', 'type': 'Document'}, {'id': '1010311341477778396', 'metadata': {'minimum_nights': 1.0, 'longitude': -99.16, 'bathrooms': 2.0, 'room_type': 'Entire home/apt', 'has_availability': True, 'latitude': 19.43, 'amenities': ['Shampoo', 'Carbon monoxide alarm', 'Other gas stove', 'Free dryer \\u2013 In unit', 'Iron', 'Crib - available upon request', 'Dishes and silverware', 'LG refrigerator', 'Cleaning products', 'Hot water', 'Blender', 'TV', 'Elevator', 'Lockbox', 'Kitchen', 'Toaster', 'Clothing storage', 'Patio or balcony', 'Washer', 'Wifi', 'Self check-in', 'Portable fans', 'Free parking on premises', 'Hangers', 'Smoke alarm', 'Coffee maker', 'Dining table', 'Coffee', 'Microwave', 'Extra pillows and blankets', 'Bed linens'], 'bedrooms': 2.0, 'price': 2112.0, 'bathrooms_text': '2 baths', 'neighbourhood_cleansed': 'Cuauhtémoc', 'review_scores_accuracy': 5.0, 'beds': 4.0, 'property_type': 'Entire condo', 'maximum_nights': 1125.0}, 'page_content': "Stay in the heart of Mexico City whether your trip is for business or pleasure. You've found the ideal place, with everything at hand: restaurants, bars, museums, embassies, theaters, parks, shopping malls, etc., near areas such as Chapultepec, Historic Center, Polanco, Colonia Roma and Col. Condesa, a few steps from the junction of the 2 most important avenues of Mexico City, Paseo de la Reforma and Insurgentes, 5 minutes from the Senate of the Republic, and another 5 minutes from the Mexican Stock Exchange and American embassy.", 'type': 'Document'}, {'id': '1647909942515734864', 'metadata': {'bathrooms': 1.0, 'neighbourhood_cleansed': 'Cuauhtémoc', 'bathrooms_text': '1 bath', 'has_availability': True, 'beds': 1.0, 'review_scores_accuracy': -1.0, 'latitude': 19.44, 'amenities': ['Refrigerator', 'Host greets you', 'Clothing storage', 'Other gas stove', 'Wifi', 'Drying rack for clothing', 'Housekeeping available from 10:00\\u202fAM to 2:00\\u202fPM', '1 day a week - available at extra cost', 'Cooking basics', 'Hangers', 'Kitchen', 'Free washer \\u2013 In unit', 'Bed linens', 'Exterior security cameras on property'], 'minimum_nights': 2.0, 'property_type': 'Entire rental unit', 'longitude': -99.16, 'room_type': 'Entire home/apt', 'price': 1238.0, 'maximum_nights': 365.0, 'bedrooms': 1.0}, 'page_content': "Experience the charm of Mexico City in a space steeped in history! Enjoy a cozy apartment in one of the city's most iconic neighborhoods, perfect for those seeking an urban, cultural, and well-connected lifestyle. - On foot: 10 minutes from Av. Reforma, the Metrobus (Reforma and Revolución), and the metro (San Cosme).- Transportation: 25 minutes from the Historic Center, Chapultepec Forest, and AICM.Whether you are traveling for pleasure or for business, it has everything you need for a comfortable and pleasant stay.", 'type': 'Document'}]

# %%
[x["metadata"]["latitude"] for x in props]
# Out:
# [19.32, 19.44, 19.47, 19.32, 19.43, 19.44]

# %%
for p in props:
    print(dict(p).get("metadata").get("price"))
# Out:
# 1449.0
# 1769.0
# 1321.0
# 1712.0
# 2112.0
# 1238.0

# %%
for p in props:
    print(p["type"])
# Out:
# Document
# Document
# Document
# Document
# Document
# Document
